# %% [markdown]
# <a href="https://colab.research.google.com/github/kvinne-anc/Conflict-and-Climate-Project/blob/main/Global_LandTemp_DataCleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np

# %%
Temp = pd.read_csv('/content/GlobalLandTemperaturesByCity.csv')
Temp
# Out:
#                  dt  AverageTemperature  ...  Latitude Longitude
# 0        1743-11-01               6.068  ...    57.05N    10.33E
# 1        1743-12-01                 NaN  ...    57.05N    10.33E
# 2        1744-01-01                 NaN  ...    57.05N    10.33E
# 3        1744-02-01                 NaN  ...    57.05N    10.33E
# 4        1744-03-01                 NaN  ...    57.05N    10.33E
# ...             ...                 ...  ...       ...       ...
# 8599207  2013-05-01              11.464  ...    52.24N     5.26E
# 8599208  2013-06-01              15.043  ...    52.24N     5.26E
# 8599209  2013-07-01              18.775  ...    52.24N     5.26E
# 8599210  2013-08-01              18.025  ...    52.24N     5.26E
# 8599211  2013-09-01                 NaN  ...    52.24N     5.26E
#
# [8599212 rows x 7 columns]

# %%
Temp = Temp[Temp.Country != 'Denmark']
Temp
# Out:
#                  dt  AverageTemperature  ...  Latitude Longitude
# 3239     1743-11-01              10.013  ...    40.99N    27.69E
# 3240     1743-12-01                 NaN  ...    40.99N    27.69E
# 3241     1744-01-01                 NaN  ...    40.99N    27.69E
# 3242     1744-02-01                 NaN  ...    40.99N    27.69E
# 3243     1744-03-01                 NaN  ...    40.99N    27.69E
# ...             ...                 ...  ...       ...       ...
# 8599207  2013-05-01              11.464  ...    52.24N     5.26E
# 8599208  2013-06-01              15.043  ...    52.24N     5.26E
# 8599209  2013-07-01              18.775  ...    52.24N     5.26E
# 8599210  2013-08-01              18.025  ...    52.24N     5.26E
# 8599211  2013-09-01                 NaN  ...    52.24N     5.26E
#
# [8586256 rows x 7 columns]

# %%
Temp = Temp[Temp.Country != 'Russia']
Temp
# Out:
#                  dt  AverageTemperature  ...  Latitude Longitude
# 3239     1743-11-01              10.013  ...    40.99N    27.69E
# 3240     1743-12-01                 NaN  ...    40.99N    27.69E
# 3241     1744-01-01                 NaN  ...    40.99N    27.69E
# 3242     1744-02-01                 NaN  ...    40.99N    27.69E
# 3243     1744-03-01                 NaN  ...    40.99N    27.69E
# ...             ...                 ...  ...       ...       ...
# 8599207  2013-05-01              11.464  ...    52.24N     5.26E
# 8599208  2013-06-01              15.043  ...    52.24N     5.26E
# 8599209  2013-07-01              18.775  ...    52.24N     5.26E
# 8599210  2013-08-01              18.025  ...    52.24N     5.26E
# 8599211  2013-09-01                 NaN  ...    52.24N     5.26E
#
# [8125022 rows x 7 columns]

# %%
Temp = Temp[Temp.Country != 'Brazil']
Temp
# Out:
#                  dt  AverageTemperature  ...  Latitude Longitude
# 3239     1743-11-01              10.013  ...    40.99N    27.69E
# 3240     1743-12-01                 NaN  ...    40.99N    27.69E
# 3241     1744-01-01                 NaN  ...    40.99N    27.69E
# 3242     1744-02-01                 NaN  ...    40.99N    27.69E
# 3243     1744-03-01                 NaN  ...    40.99N    27.69E
# ...             ...                 ...  ...       ...       ...
# 8599207  2013-05-01              11.464  ...    52.24N     5.26E
# 8599208  2013-06-01              15.043  ...    52.24N     5.26E
# 8599209  2013-07-01              18.775  ...    52.24N     5.26E
# 8599210  2013-08-01              18.025  ...    52.24N     5.26E
# 8599211  2013-09-01                 NaN  ...    52.24N     5.26E
#
# [7649442 rows x 7 columns]

# %%
Temp = Temp[Temp.Country != 'United States']
Temp
# Out:
#                  dt  AverageTemperature  ...  Latitude Longitude
# 3239     1743-11-01              10.013  ...    40.99N    27.69E
# 3240     1743-12-01                 NaN  ...    40.99N    27.69E
# 3241     1744-01-01                 NaN  ...    40.99N    27.69E
# 3242     1744-02-01                 NaN  ...    40.99N    27.69E
# 3243     1744-03-01                 NaN  ...    40.99N    27.69E
# ...             ...                 ...  ...       ...       ...
# 8599207  2013-05-01              11.464  ...    52.24N     5.26E
# 8599208  2013-06-01              15.043  ...    52.24N     5.26E
# 8599209  2013-07-01              18.775  ...    52.24N     5.26E
# 8599210  2013-08-01              18.025  ...    52.24N     5.26E
# 8599211  2013-09-01                 NaN  ...    52.24N     5.26E
#
# [6962153 rows x 7 columns]

# %%
Temp = Temp[Temp.Country != 'Netherlands']
Temp
# Out:
#                  dt  AverageTemperature  ...  Latitude Longitude
# 3239     1743-11-01              10.013  ...    40.99N    27.69E
# 3240     1743-12-01                 NaN  ...    40.99N    27.69E
# 3241     1744-01-01                 NaN  ...    40.99N    27.69E
# 3242     1744-02-01                 NaN  ...    40.99N    27.69E
# 3243     1744-03-01                 NaN  ...    40.99N    27.69E
# ...             ...                 ...  ...       ...       ...
# 8595968  2013-05-01              22.982  ...    32.95N    12.45E
# 8595969  2013-06-01              24.638  ...    32.95N    12.45E
# 8595970  2013-07-01              27.207  ...    32.95N    12.45E
# 8595971  2013-08-01              27.778  ...    32.95N    12.45E
# 8595972  2013-09-01                 NaN  ...    32.95N    12.45E
#
# [6884417 rows x 7 columns]

# %%
Temp = Temp[Temp.Country != 'Thailand']
Temp
# Out:
#                  dt  AverageTemperature  ...  Latitude Longitude
# 3239     1743-11-01              10.013  ...    40.99N    27.69E
# 3240     1743-12-01                 NaN  ...    40.99N    27.69E
# 3241     1744-01-01                 NaN  ...    40.99N    27.69E
# 3242     1744-02-01                 NaN  ...    40.99N    27.69E
# 3243     1744-03-01                 NaN  ...    40.99N    27.69E
# ...             ...                 ...  ...       ...       ...
# 8595968  2013-05-01              22.982  ...    32.95N    12.45E
# 8595969  2013-06-01              24.638  ...    32.95N    12.45E
# 8595970  2013-07-01              27.207  ...    32.95N    12.45E
# 8595971  2013-08-01              27.778  ...    32.95N    12.45E
# 8595972  2013-09-01                 NaN  ...    32.95N    12.45E
#
# [6834732 rows x 7 columns]

# %%
Temp = Temp[Temp.Country != 'Poland']
Temp
# Out:
#                  dt  AverageTemperature  ...  Latitude Longitude
# 3239     1743-11-01              10.013  ...    40.99N    27.69E
# 3240     1743-12-01                 NaN  ...    40.99N    27.69E
# 3241     1744-01-01                 NaN  ...    40.99N    27.69E
# 3242     1744-02-01                 NaN  ...    40.99N    27.69E
# 3243     1744-03-01                 NaN  ...    40.99N    27.69E
# ...             ...                 ...  ...       ...       ...
# 8595968  2013-05-01              22.982  ...    32.95N    12.45E
# 8595969  2013-06-01              24.638  ...    32.95N    12.45E
# 8595970  2013-07-01              27.207  ...    32.95N    12.45E
# 8595971  2013-08-01              27.778  ...    32.95N    12.45E
# 8595972  2013-09-01                 NaN  ...    32.95N    12.45E
#
# [6711650 rows x 7 columns]

# %%
Temp = Temp[Temp.Country != 'Germany']
Temp
# Out:
#                  dt  AverageTemperature  ...  Latitude Longitude
# 3239     1743-11-01              10.013  ...    40.99N    27.69E
# 3240     1743-12-01                 NaN  ...    40.99N    27.69E
# 3241     1744-01-01                 NaN  ...    40.99N    27.69E
# 3242     1744-02-01                 NaN  ...    40.99N    27.69E
# 3243     1744-03-01                 NaN  ...    40.99N    27.69E
# ...             ...                 ...  ...       ...       ...
# 8595968  2013-05-01              22.982  ...    32.95N    12.45E
# 8595969  2013-06-01              24.638  ...    32.95N    12.45E
# 8595970  2013-07-01              27.207  ...    32.95N    12.45E
# 8595971  2013-08-01              27.778  ...    32.95N    12.45E
# 8595972  2013-09-01                 NaN  ...    32.95N    12.45E
#
# [6449291 rows x 7 columns]

# %%
Temp = Temp[Temp.Country != 'Haiti']
Temp
# Out:
#                  dt  AverageTemperature  ...  Latitude Longitude
# 3239     1743-11-01              10.013  ...    40.99N    27.69E
# 3240     1743-12-01                 NaN  ...    40.99N    27.69E
# 3241     1744-01-01                 NaN  ...    40.99N    27.69E
# 3242     1744-02-01                 NaN  ...    40.99N    27.69E
# 3243     1744-03-01                 NaN  ...    40.99N    27.69E
# ...             ...                 ...  ...       ...       ...
# 8595968  2013-05-01              22.982  ...    32.95N    12.45E
# 8595969  2013-06-01              24.638  ...    32.95N    12.45E
# 8595970  2013-07-01              27.207  ...    32.95N    12.45E
# 8595971  2013-08-01              27.778  ...    32.95N    12.45E
# 8595972  2013-09-01                 NaN  ...    32.95N    12.45E
#
# [6437894 rows x 7 columns]

# %%
Temp = Temp[Temp.Country != 'Romania']
Temp
# Out:
#                  dt  AverageTemperature  ...  Latitude Longitude
# 3239     1743-11-01              10.013  ...    40.99N    27.69E
# 3240     1743-12-01                 NaN  ...    40.99N    27.69E
# 3241     1744-01-01                 NaN  ...    40.99N    27.69E
# 3242     1744-02-01                 NaN  ...    40.99N    27.69E
# 3243     1744-03-01                 NaN  ...    40.99N    27.69E
# ...             ...                 ...  ...       ...       ...
# 8595968  2013-05-01              22.982  ...    32.95N    12.45E
# 8595969  2013-06-01              24.638  ...    32.95N    12.45E
# 8595970  2013-07-01              27.207  ...    32.95N    12.45E
# 8595971  2013-08-01              27.778  ...    32.95N    12.45E
# 8595972  2013-09-01                 NaN  ...    32.95N    12.45E
#
# [6356919 rows x 7 columns]

# %%
Temp = Temp[Temp.Country != 'Ghana']
Temp
# Out:
#                  dt  AverageTemperature  ...  Latitude Longitude
# 3239     1743-11-01              10.013  ...    40.99N    27.69E
# 3240     1743-12-01                 NaN  ...    40.99N    27.69E
# 3241     1744-01-01                 NaN  ...    40.99N    27.69E
# 3242     1744-02-01                 NaN  ...    40.99N    27.69E
# 3243     1744-03-01                 NaN  ...    40.99N    27.69E
# ...             ...                 ...  ...       ...       ...
# 8595968  2013-05-01              22.982  ...    32.95N    12.45E
# 8595969  2013-06-01              24.638  ...    32.95N    12.45E
# 8595970  2013-07-01              27.207  ...    32.95N    12.45E
# 8595971  2013-08-01              27.778  ...    32.95N    12.45E
# 8595972  2013-09-01                 NaN  ...    32.95N    12.45E
#
# [6339126 rows x 7 columns]

# %%
Temp = Temp[Temp.Country != 'Japan']
Temp
# Out:
#                  dt  AverageTemperature  ...  Latitude Longitude
# 3239     1743-11-01              10.013  ...    40.99N    27.69E
# 3240     1743-12-01                 NaN  ...    40.99N    27.69E
# 3241     1744-01-01                 NaN  ...    40.99N    27.69E
# 3242     1744-02-01                 NaN  ...    40.99N    27.69E
# 3243     1744-03-01                 NaN  ...    40.99N    27.69E
# ...             ...                 ...  ...       ...       ...
# 8595968  2013-05-01              22.982  ...    32.95N    12.45E
# 8595969  2013-06-01              24.638  ...    32.95N    12.45E
# 8595970  2013-07-01              27.207  ...    32.95N    12.45E
# 8595971  2013-08-01              27.778  ...    32.95N    12.45E
# 8595972  2013-09-01                 NaN  ...    32.95N    12.45E
#
# [5980457 rows x 7 columns]

# %%
Temp = Temp[Temp.Country != 'Cuba']
Temp
# Out:
#                  dt  AverageTemperature  ...  Latitude Longitude
# 3239     1743-11-01              10.013  ...    40.99N    27.69E
# 3240     1743-12-01                 NaN  ...    40.99N    27.69E
# 3241     1744-01-01                 NaN  ...    40.99N    27.69E
# 3242     1744-02-01                 NaN  ...    40.99N    27.69E
# 3243     1744-03-01                 NaN  ...    40.99N    27.69E
# ...             ...                 ...  ...       ...       ...
# 8595968  2013-05-01              22.982  ...    32.95N    12.45E
# 8595969  2013-06-01              24.638  ...    32.95N    12.45E
# 8595970  2013-07-01              27.207  ...    32.95N    12.45E
# 8595971  2013-08-01              27.778  ...    32.95N    12.45E
# 8595972  2013-09-01                 NaN  ...    32.95N    12.45E
#
# [5948411 rows x 7 columns]

# %%
Temp = Temp[Temp.Country != 'Colombia']
Temp
# Out:
#                  dt  AverageTemperature  ...  Latitude Longitude
# 3239     1743-11-01              10.013  ...    40.99N    27.69E
# 3240     1743-12-01                 NaN  ...    40.99N    27.69E
# 3241     1744-01-01                 NaN  ...    40.99N    27.69E
# 3242     1744-02-01                 NaN  ...    40.99N    27.69E
# 3243     1744-03-01                 NaN  ...    40.99N    27.69E
# ...             ...                 ...  ...       ...       ...
# 8595968  2013-05-01              22.982  ...    32.95N    12.45E
# 8595969  2013-06-01              24.638  ...    32.95N    12.45E
# 8595970  2013-07-01              27.207  ...    32.95N    12.45E
# 8595971  2013-08-01              27.778  ...    32.95N    12.45E
# 8595972  2013-09-01                 NaN  ...    32.95N    12.45E
#
# [5860394 rows x 7 columns]

# %%
Temp = Temp[Temp.Country != 'Peru']
Temp
# Out:
#                  dt  AverageTemperature  ...  Latitude Longitude
# 3239     1743-11-01              10.013  ...    40.99N    27.69E
# 3240     1743-12-01                 NaN  ...    40.99N    27.69E
# 3241     1744-01-01                 NaN  ...    40.99N    27.69E
# 3242     1744-02-01                 NaN  ...    40.99N    27.69E
# 3243     1744-03-01                 NaN  ...    40.99N    27.69E
# ...             ...                 ...  ...       ...       ...
# 8595968  2013-05-01              22.982  ...    32.95N    12.45E
# 8595969  2013-06-01              24.638  ...    32.95N    12.45E
# 8595970  2013-07-01              27.207  ...    32.95N    12.45E
# 8595971  2013-08-01              27.778  ...    32.95N    12.45E
# 8595972  2013-09-01                 NaN  ...    32.95N    12.45E
#
# [5822761 rows x 7 columns]

# %%
Temp = Temp[Temp.Country != 'United Kingdom']
Temp
# Out:
#                  dt  AverageTemperature  ...  Latitude Longitude
# 3239     1743-11-01              10.013  ...    40.99N    27.69E
# 3240     1743-12-01                 NaN  ...    40.99N    27.69E
# 3241     1744-01-01                 NaN  ...    40.99N    27.69E
# 3242     1744-02-01                 NaN  ...    40.99N    27.69E
# 3243     1744-03-01                 NaN  ...    40.99N    27.69E
# ...             ...                 ...  ...       ...       ...
# 8595968  2013-05-01              22.982  ...    32.95N    12.45E
# 8595969  2013-06-01              24.638  ...    32.95N    12.45E
# 8595970  2013-07-01              27.207  ...    32.95N    12.45E
# 8595971  2013-08-01              27.778  ...    32.95N    12.45E
# 8595972  2013-09-01                 NaN  ...    32.95N    12.45E
#
# [5602509 rows x 7 columns]

# %%
Temp = Temp[Temp.Country != 'Mexico']
Temp
# Out:
#                  dt  AverageTemperature  ...  Latitude Longitude
# 3239     1743-11-01              10.013  ...    40.99N    27.69E
# 3240     1743-12-01                 NaN  ...    40.99N    27.69E
# 3241     1744-01-01                 NaN  ...    40.99N    27.69E
# 3242     1744-02-01                 NaN  ...    40.99N    27.69E
# 3243     1744-03-01                 NaN  ...    40.99N    27.69E
# ...             ...                 ...  ...       ...       ...
# 8595968  2013-05-01              22.982  ...    32.95N    12.45E
# 8595969  2013-06-01              24.638  ...    32.95N    12.45E
# 8595970  2013-07-01              27.207  ...    32.95N    12.45E
# 8595971  2013-08-01              27.778  ...    32.95N    12.45E
# 8595972  2013-09-01                 NaN  ...    32.95N    12.45E
#
# [5392949 rows x 7 columns]

# %%
Temp = Temp[Temp.Country != 'Indonesia']
Temp
# Out:
#                  dt  AverageTemperature  ...  Latitude Longitude
# 3239     1743-11-01              10.013  ...    40.99N    27.69E
# 3240     1743-12-01                 NaN  ...    40.99N    27.69E
# 3241     1744-01-01                 NaN  ...    40.99N    27.69E
# 3242     1744-02-01                 NaN  ...    40.99N    27.69E
# 3243     1744-03-01                 NaN  ...    40.99N    27.69E
# ...             ...                 ...  ...       ...       ...
# 8595968  2013-05-01              22.982  ...    32.95N    12.45E
# 8595969  2013-06-01              24.638  ...    32.95N    12.45E
# 8595970  2013-07-01              27.207  ...    32.95N    12.45E
# 8595971  2013-08-01              27.778  ...    32.95N    12.45E
# 8595972  2013-09-01                 NaN  ...    32.95N    12.45E
#
# [5069694 rows x 7 columns]

# %%
Temp = Temp[Temp.Country != 'Portugal']

# %%
Temp = Temp[Temp.Country != 'Switzerland']

# %%
Temp = Temp[Temp.Country != 'Moldova']

# %%
Temp = Temp[Temp.Country != 'Burma']

# %%
Temp = Temp[Temp.Country != 'France']

# %%
Temp = Temp[Temp.Country != 'Sierra Leone']

# %%
Temp = Temp[Temp.Country != 'Congo (Democratic Republic Of The)']

# %%
Temp = Temp[Temp.Country != 'Venezuela']

# %%
Temp = Temp[Temp.Country != 'Belgium']

# %%
Temp = Temp[Temp.Country != 'Vietnam']

# %%
Temp = Temp[Temp.Country != 'Australia']

# %%
Temp = Temp[Temp.Country != 'Central African Republic']

# %%
Temp = Temp[Temp.Country != 'Nigeria']

# %%
Temp = Temp[Temp.Country != 'Sweden']

# %%
Temp = Temp[Temp.Country != 'Argentina']

# %%
Temp = Temp[Temp.Country != 'Norway']

# %%
Temp = Temp[Temp.Country != 'Finland']

# %%
Temp = Temp[Temp.Country != 'Spain']

# %%
Temp = Temp[Temp.Country != 'Italy']

# %%
Temp = Temp[Temp.Country != 'Greece']

# %%
Temp = Temp[Temp.Country != 'Chile']

# %%
Temp = Temp[Temp.Country != 'Ecuador']

# %%
Temp = Temp[Temp.Country != 'New Zealand']

# %%
Temp = Temp[Temp.Country != 'Kenya']

# %%
Temp = Temp[Temp.Country != 'Malaysia']

# %%
Temp = Temp[Temp.Country != 'Canada']

# %%
Temp = Temp[Temp.Country != 'Slovakia']

# %%
Temp = Temp[Temp.Country != 'Hungary']

# %%
Temp = Temp[Temp.Country != 'Serbia']

# %%
Temp = Temp[Temp.Country != 'Ukraine']

# %%
Temp = Temp[Temp.Country != 'Bulgaria']

# %%
Temp = Temp[Temp.Country != 'Austria']

# %%
Temp = Temp[Temp.Country != 'Libya']

# %%
Temp = Temp[Temp.Country != 'Latvia']

# %%
Temp = Temp[Temp.Country != 'Algeria']

# %%
Temp = Temp[Temp.Country != 'Morocco']

# %%
Temp = Temp[Temp.Country != 'Ireland']

# %%
Temp = Temp[Temp.Country != 'Bolivia']

# %%
Temp = Temp[Temp.Country != 'Paraguay']

# %%
Temp = Temp[Temp.Country != 'Uruguay']

# %%
Temp = Temp[Temp.Country != 'Puerto Rico']

# %%
Temp = Temp[Temp.Country != 'Nicaragua']

# %%
Temp = Temp[Temp.Country != 'Guatemala']

# %%
Temp = Temp[Temp.Country != 'Madagascar']

# %%
Temp = Temp[Temp.Country != 'Philippines']

# %%
Temp = Temp[Temp.Country != 'Ethiopia']

# %%
Temp = Temp[Temp.Country != 'Angola']

# %%
Temp = Temp[Temp.Country != 'Tunisia']

# %%
Temp = Temp[Temp.Country != 'Mauritania']

# %%
Temp = Temp[Temp.Country != 'Mozambique']

# %%
Temp = Temp[Temp.Country != 'Belarus']

# %%
Temp = Temp[Temp.Country != 'Somalia']

# %%
Temp = Temp[Temp.Country != 'Tanzania']

# %%
Temp = Temp[Temp.Country != 'Nambia']

# %%
Temp = Temp[Temp.Country != 'Zimbabwe']

# %%
Temp = Temp[Temp.Country != 'Zambia']

# %%
Temp = Temp[Temp.Country != 'Mali']

# %%
Temp = Temp[Temp.Country != 'Burkina Faso']

# %%
Temp = Temp[Temp.Country != 'Guinea']

# %%
Temp = Temp[Temp.Country != 'Papua New Guinea']

# %%
Temp = Temp[Temp.Country != 'Albania']

# %%
Temp = Temp[Temp.Country != 'Honduras']

# %%
Temp = Temp[Temp.Country != 'Panama']

# %%
Temp = Temp[Temp.Country != 'Costa Rica']

# %%
Temp = Temp[Temp.Country != 'Guyana']

# %%
Temp = Temp[Temp.Country != 'Dominican Republic']

# %%
Temp = Temp[Temp.Country != 'Saudi Arabia']

# %%
Temp = Temp[Temp.Country != 'Cameroon']

# %%
Temp = Temp[Temp.Country != "Côte D'Ivoire"]

# %%
Temp = Temp[Temp.Country != 'Sri Lanka']

# %%
Temp = Temp[Temp.Country != 'Czech Republic']

# %%
Temp = Temp[Temp.Country != 'South Africa']
Temp
# Out:
#                  dt  AverageTemperature  ...  Latitude Longitude
# 3239     1743-11-01              10.013  ...    40.99N    27.69E
# 3240     1743-12-01                 NaN  ...    40.99N    27.69E
# 3241     1744-01-01                 NaN  ...    40.99N    27.69E
# 3242     1744-02-01                 NaN  ...    40.99N    27.69E
# 3243     1744-03-01                 NaN  ...    40.99N    27.69E
# ...             ...                 ...  ...       ...       ...
# 8589600  2013-05-01              19.473  ...    28.13N   106.36E
# 8589601  2013-06-01              23.670  ...    28.13N   106.36E
# 8589602  2013-07-01              26.159  ...    28.13N   106.36E
# 8589603  2013-08-01              25.502  ...    28.13N   106.36E
# 8589604  2013-09-01                 NaN  ...    28.13N   106.36E
#
# [2846737 rows x 7 columns]

# %%
Temp.sample(25)
# Out:
#                  dt  AverageTemperature  ...  Latitude Longitude
# 8259452  1880-10-01               7.899  ...    39.38N   106.13E
# 2785206  1945-05-01              31.325  ...    31.35N    73.51E
# 3658353  1855-12-01              20.637  ...    18.48N    79.44E
# 3942571  1882-04-01              31.118  ...    21.70N    82.21E
# 2178979  2009-03-01              -6.644  ...    52.24N    76.20E
# 779776   1935-02-01              -2.207  ...    40.99N   121.42E
# 4350694  1885-06-01              25.052  ...    24.92N   117.04E
# 3801959  1869-07-01              28.300  ...    23.31N    90.00E
# 6705369  1889-02-01               8.475  ...    26.52N   118.21E
# 3025337  1996-11-01              21.393  ...    24.92N   120.59E
# 1222123  1870-06-01              30.865  ...    21.70N    77.02E
# 8074408  2002-06-01              28.556  ...    18.48N    82.82E
# 3432038  1935-10-01              16.123  ...    36.17N   119.34E
# ...

# %%
Temp.to_csv(r'C:\Users\surfb\OneDrive\Desktop\Temp_C.csv', header=True)
print (Temp)
# Out:
#                  dt  AverageTemperature  ...  Latitude Longitude
# 3239     1743-11-01              10.013  ...    40.99N    27.69E
# 3240     1743-12-01                 NaN  ...    40.99N    27.69E
# 3241     1744-01-01                 NaN  ...    40.99N    27.69E
# 3242     1744-02-01                 NaN  ...    40.99N    27.69E
# 3243     1744-03-01                 NaN  ...    40.99N    27.69E
# ...             ...                 ...  ...       ...       ...
# 8589600  2013-05-01              19.473  ...    28.13N   106.36E
# 8589601  2013-06-01              23.670  ...    28.13N   106.36E
# 8589602  2013-07-01              26.159  ...    28.13N   106.36E
# 8589603  2013-08-01              25.502  ...    28.13N   106.36E
# 8589604  2013-09-01                 NaN  ...    28.13N   106.36E
#
# [2846737 rows x 7 columns]
